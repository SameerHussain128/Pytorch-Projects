# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread(r'C:\Users\SAMEER\Projects\Pytorch\images\elephant.jpeg')

# %%
img2 = cv2.imread(r'C:\Users\SAMEER\Projects\Pytorch\images\horse white.jpeg')

# %%
plt.imshow(img2)

# %%
plt.imshow(img)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (194, 259, 3)

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
fix_img
# Out:
# array([[[199, 206, 222],
#         [199, 206, 222],
#         [199, 206, 222],
#         ...,
#         [ 56,  52,  41],
#         [ 48,  46,  33],
#         [ 51,  49,  36]],
#
#        [[199, 206, 222],
#         [199, 206, 222],
#         [199, 206, 222],
#         ...,
#         [ 50,  48,  36],
#         [ 55,  53,  40],
#         [ 67,  65,  53]],
#
#        [[199, 206, 222],
#         [199, 206, 222],
#         [200, 207, 223],
#         ...,
#         [ 35,  32,  23],
#         [ 41,  41,  29],
#         [ 43,  43,  33]],
#
#        ...,
#
#        [[187, 148, 109],
#         [187, 148, 107],
#         [186, 147, 108],
#         ...,
#         [190, 148, 108],
#         [200, 158, 118],
#         [182, 140, 100]],
#
#        [[208, 166, 126],
#         [193, 151, 109],
#         [188, 146, 106],
#         ...,
#         [187, 145, 107],
#         [184, 145, 106],
#         [184, 145, 106]],
#
#        [[194, 152, 110],
#         [182, 140,  98],
#         [181, 139,  97],
# ...

# %%
fix_img.shape
# Out:
# (194, 259, 3)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread(r'C:\Users\SAMEER\Projects\Pytorch\images\elephant.jpeg', cv2.IMREAD_GRAYSCALE)
img_gray
# Out:
# array([[206, 206, 206, ...,  52,  45,  48],
#        [206, 206, 206, ...,  47,  52,  64],
#        [206, 206, 207, ...,  32,  40,  42],
#        ...,
#        [155, 155, 154, ..., 156, 166, 148],
#        [174, 159, 154, ..., 153, 152, 152],
#        [160, 148, 147, ..., 153, 153, 152]], dtype=uint8)

# %%
img_gray.min()
# Out:
# 0

# %%
img_gray.max()
# Out:
# 255

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap = 'gray')

# %%
plt.imshow(img_gray, cmap = 'magma')

# %%
plt.imshow(img_gray, cmap = 'black')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 plt.imshow(img_gray, cmap = 'black')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2695, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2689 @_copy_docstring_and_deprecators(Axes.imshow)
#    2690 def imshow(
#    2691         X, cmap=None, norm=None, *, aspect=None, interpolation=None,
#    2692         alpha=None, vmin=None, vmax=None, origin=None, extent=None,
#    2693         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2694         resample=None, url=None, data=None, **kwargs):
# -> 2695     __ret = gca().imshow(
#    2696         X, cmap=cmap, norm=norm, aspect=aspect,
# ...

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (194, 259, 3)

# %%
cv2.

# %%
259/2
# Out:
# 129.5

# %%
imgf = cv2.flip(fix_img,0)
plt.imshow(imgf)

# %%
imgf = cv2.flip(fix_img, 1)
plt.imshow(imgf)

# %%
imgf = cv2.flip(fix_img, 3)
plt.imshow(imgf)

# %%
cv2.imwrite('new genai image.jpg', fix_img)
# Out:
# True
